# %%
import pandas as pd

# %%
df = pd.read_csv('bottoms.csv', index_col=0)

# %%
df[['rstd']].boxplot()
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x10d1d6710>],
#  'caps': [<matplotlib.lines.Line2D at 0x10d1d3d10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x10d1d9150>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x10d1d6c10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x10d1d3550>,
#   <matplotlib.lines.Line2D at 0x10d1d3790>]}

# %%
dfs = df.sort('rstd').dropna()

# %%
dfs[-100:-50]
# Out:
#                                               company_name      ma50     ma100       ma200      rstd
# bsecode
# 532670                            SHREE RENUKA SUGARS LTD.   17.9570   21.0395    25.53050  0.177066
# 532814                                         INDIAN BANK  114.3970  139.0390   163.79875  0.177604
# 532331                                  AJANTA PHARMA LTD.  954.5350  869.5525   665.96075  0.178664
# 509053                               BANAS FINANCE LIMITED   34.1490   30.3915    23.76160  0.178687
# 500102                          BALLARPUR INDUSTRIES LTD.,   12.9864   15.2072    18.52135  0.178877
# 503031                              PENINSULA LAND LIMITED   39.3260   43.2480    55.19225  0.179962
# 530273                               LIBERTY PHOSPHATE LTD  129.7420  172.5955   186.15825  0.180850
# 500085                 CHAMBAL FERTILISERS & CHEMICALS LTD   38.7060   44.4850    55.18525  0.181271
# ...
